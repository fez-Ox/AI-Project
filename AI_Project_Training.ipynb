# %%
import kagglehub
path = kagglehub.dataset_download("ankitdhiman7/race-dataset")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 70.0M/70.0M [00:00<00:00, 156MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/ankitdhiman7/race-dataset/versions/1

# %%
# !git clone https://github.com/fez-Ox/AI-Project.git
# %cd AI-Project
# !mkdir -p data/raw
# !cp -r /root/.cache/kagglehub/datasets/ankitdhiman7/race-dataset/versions/1/* ./data/raw
# !pip install -r requirements.txt
# Out:
# Cloning into 'AI-Project'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 42 (delta 18), reused 39 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 14.37 KiB | 7.18 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# /content/AI-Project
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 59.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 41.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 54.0 MB/s eta 0:00:00
# ...

# %%
# Preprocessing Data
# !python src/preprocessing.py
# Out:
# Processing data/raw/train.csv...
# Saved processed data to data/processed/train_binary.csv
# Processing data/raw/dev.csv...
# Saved processed data to data/processed/val_binary.csv
# Processing data/raw/test.csv...
# Saved processed data to data/processed/test_binary.csv

# %%
# Training Model A
# !python src/model_a_train.py
# Out:
# Initializing TF-IDF Vectorizer...
# Fitting Vectorizer and Transforming Training Data...
# Computing Word Overlap Features for Training Data...
# Running Unsupervised Component (K-Means Clustering)...
# K-Means Silhouette Score: 0.0040
#
# Training Logistic Regression Model...
# Training Calibrated Linear SVM Model...
# Training Ensemble (Soft Voting) Model...
# Saving Models and Vectorizer...
# Training complete. Run src/evaluate.py to see metrics.

# %%
# Training Model B
# !python src/model_b_train.py
# Out:
# Loading training data for Model B...
# Found 25135 unique articles.
# Tokenizing corpus (this may take a moment)...
# Training Global Word2Vec model on 443691 sentences...
# Model B (Word2Vec) saved to models/model_b/word2vec.model!

# %%
# !python src/evaluate.py
# Out:
# Loading evaluation dataset from data/processed/test_binary.csv...
# ...
#  MODEL A - VERIFICATION METRICS
# ...
#
# --- Logistic Regression ---
# Binary Accuracy: 0.5034
# Macro F1: 0.4797
# Confusion Matrix:
#  [[125993 137605]
#  [ 36930  50936]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.77      0.48      0.59    263598
#            1       0.27      0.58      0.37     87866
#
#     accuracy                           0.50    351464
#    macro avg       0.52      0.53      0.48    351464
# weighted avg       0.65      0.50      0.54    351464
#
# >>> Exact Match (Real MCQ Accuracy): 0.3154 <<<
#
# --- Linear SVM ---
# Binary Accuracy: 0.7500
# Macro F1: 0.4286
# Confusion Matrix:
#  [[263598      0]
#  [ 87866      0]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86    263598
#            1       0.00      0.00      0.00     87866
#
# ...

# %%
# !git pull
# Out:
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 713 bytes | 356.00 KiB/s, done.
# From https://github.com/fez-Ox/AI-Project
#    e50a193..d59c453  main       -> origin/main
# Updating e50a193..d59c453
# Fast-forward
#  src/model_a_train.py | 20 +++++++++++++++++---
#  1 file changed, 17 insertions(+), 3 deletions(-)
